# %% [markdown]
# # Home sweet home

# %% [markdown]
# *Choose a dog to adopt and find out the best location for her/him!*

# %% [markdown]
# [protectora.jpg]("src/protectora.jpg")

# %% [markdown]
# Which is the best home for a dog on adoption based on its size and some characteristics of the place where it'll go to live(square mts, presence of terrace/garden...)?

# %% [markdown]
# ## 0.Import libraries

# %%
import numpy as np
import pandas as pd
import re
import time

# Options for DataFrame visualization:
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 40)
# Option to show not truncated cells in pandas
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## 1. Importing dataframes

# %% [markdown]
# #### · Protectora Barcelona

# %%
# Share data between Jupyter Notebooks
# %store -r adoptable_dogs

# %%
adoptable_dogs = pd.read_csv('output/'+ adoptable_dogs)

# %%
adoptable_dogs.head(2)
# Out:
#   Nombre     Caracteristicas                                                           Foto    URL  Codigo  Animal    Sexo  Medidas    Edad         Color     Raza Nacimiento  Entrada  \
# 0  Nerea  ¡¡ RESERVADA !!     https://server03.protectorabcn.es/7428-home_default/nerea.jpg  nerea  78      Perros  Hembra  Mediano  Adulto  Marrón claro  Mestizo  2010       02/2014
# 1  Gina   Curiosa y elegante  https://server03.protectorabcn.es/7720-home_default/gina.jpg   gina   39      Perros  Hembra  Grande   Adulto  Blanco        Mestizo  2010       02/2014
#
# ...

# %%
adoptable_dogs.shape
# Out:
# (39, 16)

# %% [markdown]
# Selecting columns

# %%
adoptable_dogs = adoptable_dogs[['Nombre','Caracteristicas','Sexo','Medidas','Edad','Color','Raza','Nacimiento','Entrada','Años perrera','Estado']]
adoptable_dogs
# Out:
#        Nombre                   Caracteristicas    Sexo           Medidas      Edad              Color                      Raza Nacimiento  Entrada Años perrera       Estado
# 0   Nerea      ¡¡ RESERVADA !!                   Hembra  Mediano           Adulto    Marrón claro       Mestizo                   2010       02/2014  4.1 years    En Adopción
# 1   Gina       Curiosa y elegante                Hembra  Grande            Adulto    Blanco             Mestizo                   2010       02/2014  4.1 years    En Adopción
# 2   Horus      Una familia con dedicación        Macho   Grande            Joven     Marron oscuro      Mestizo de Pastor Alemán  03/2016    09/2017  1.5 years    En Adopción
# 3   Muñeca     Preparada para volver a empezar   Hembra  Mediano           Adulto    Negro              Mestizo                   02/2012    07/2018  6.4 years    En Adopción
# ...

# %%
adoptable_dogs.shape
# Out:
# (39, 11)

# %% [markdown]
# #### · API idealista

# %%
# Share data between Jupyter Notebooks
# %store -r homes_BCN

# %%
# homes_BCN = pd.read_csv('output/'+ homes_BCN)
