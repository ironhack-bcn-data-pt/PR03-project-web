# %%
import re
import json
import requests
from selenium import webdriver
import geckodriver_autoinstaller
import pandas as pd
import time

# %%
#Hemos generado un archivo para poder guardar aquí la contraseña e usuario
with open('credentials.json') as f:
    credentials = json.load(f)
    
usuario = credentials['usuario']
password=credentials['password']

# %%
from linkedin_api import Linkedin
# Nos autenticamos en Linkedin
api = Linkedin(usuario, password)

# %%
jobs = api.search_jobs(keywords='Intern', companies=None, experience=None, job_type=None, job_title=None, industries=None, location_name='Barcelona', remote=True, listed_at=86400, limit=10, offset=0)

# %%
dir(api)
# Out:
# ['_MAX_REPEATED_REQUESTS',
#  '_MAX_SEARCH_COUNT',
#  '_MAX_UPDATE_COUNT',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_fetch',
#  '_post',
#  'client',
#  'get_company',
#  'get_company_updates',
#  'get_conversation',
#  'get_conversation_details',
#  'get_conversations',
#  'get_current_profile_views',
#  'get_invitations',
#  'get_profile',
#  'get_profile_connections',
#  'get_profile_contact_info',
#  'get_profile_member_badges',
#  'get_profile_network_info',
#  'get_profile_privacy_settings',
#  'get_profile_skills',
#  'get_profile_updates',
#  'get_school',
#  'get_user_profile',
#  'logger',
#  'mark_conversation_as_seen',
#  'remove_connection',
#  'reply_invitation',
#  'search',
#  'search_companies',
#  'search_jobs',
#  'search_people',
#  'send_message',
#  'track',
#  'unfollow_entity',
#  'view_profile']

# %%
help(api.get_company)
# Out:
# Help on method get_company in module linkedin_api.linkedin:
#
# get_company(public_id) method of linkedin_api.linkedin.Linkedin instance
#     Fetch data about a given LinkedIn company.
#
#     :param public_id: LinkedIn public ID for a company
#     :type public_id: str
#
#     :return: Company data
#     :rtype: dict

# %%
jobs_df = pd.DataFrame(jobs)
jobs_df
# Out:
#                                       salaryInsights  \
# 0  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 1  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 2  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 3  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 4  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 5  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 6  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 7  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 8  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 9  {'lockModuleShown': True, 'salaryExplorerUrl':...
#
#                       dashEntityUrn  \
# 0  urn:li:fsd_jobPosting:2789801957
# 1  urn:li:fsd_jobPosting:2659225588
# 2  urn:li:fsd_jobPosting:2798062915
# 3  urn:li:fsd_jobPosting:2794290431
# 4  urn:li:fsd_jobPosting:2766593461
# 5  urn:li:fsd_jobPosting:2751447445
# 6  urn:li:fsd_jobPosting:2755937274
# 7  urn:li:fsd_jobPosting:2800730136
# 8  urn:li:fsd_jobPosting:2788830334
# 9  urn:li:fsd_jobPosting:2770419858
#
#                                       companyDetails jobState  \
# 0  {'company': 'urn:li:fs_normalized_company:1619...   LISTED
# 1  {'company': 'urn:li:fs_normalized_company:1115...   LISTED
# 2  {'company': 'urn:li:fs_normalized_company:1829...   LISTED
# 3  {'company': 'urn:li:fs_normalized_company:7087...   LISTED
# 4  {'company': 'urn:li:fs_normalized_company:9262...   LISTED
# 5  {'company': 'urn:li:fs_normalized_company:2458...   LISTED
# 6  {'company': 'urn:li:fs_normalized_company:1586...   LISTED
# 7  {'company': 'urn:li:fs_normalized_company:9262...   LISTED
# 8  {'company': 'urn:li:fs_normalized_company:2289...   LISTED
# 9  {'company': 'urn:li:fs_normalized_company:3720...   LISTED
#
#                                                title duration  \
# 0                 Intern Masters Business (51006201)     None
# 1         SAP iXp Intern - Digital Demand Strategist     None
# 2                                 Performance Intern     None
# 3                 User Support Representative Intern     None
# 4                     Expansion Intern (They/She/He)     None
# 5                 Performance Management / MI Intern     None
# 6               Business Intelligence Intern - Spain     None
# 7                People Process Intern (They/She/He)     None
# 8                            Campaign Manager Intern     None
# 9  Business and Sales Compensation Analyst Intern...     None
#
#                                     entityUrn briefBenefitsDescription  \
# 0  urn:li:fs_normalized_jobPosting:2789801957
# 1  urn:li:fs_normalized_jobPosting:2659225588
# 2  urn:li:fs_normalized_jobPosting:2798062915
# 3  urn:li:fs_normalized_jobPosting:2794290431
# 4  urn:li:fs_normalized_jobPosting:2766593461
# 5  urn:li:fs_normalized_jobPosting:2751447445
# 6  urn:li:fs_normalized_jobPosting:2755937274
# 7  urn:li:fs_normalized_jobPosting:2800730136
# 8  urn:li:fs_normalized_jobPosting:2788830334
# 9  urn:li:fs_normalized_jobPosting:2770419858
#
#                                          applyMethod  \
# 0  {'applyStartersPreferenceVoid': True, 'company...
# 1  {'applyStartersPreferenceVoid': True, 'company...
# 2  {'easyApplyUrl': 'https://www.linkedin.com/job...
# 3  {'easyApplyUrl': 'https://www.linkedin.com/job...
# 4  {'applyStartersPreferenceVoid': True, 'company...
# 5  {'applyStartersPreferenceVoid': True, 'company...
# 6  {'applyStartersPreferenceVoid': True, 'company...
# 7  {'applyStartersPreferenceVoid': False, 'compan...
# 8  {'unifyApplyEnabled': True, 'type': 'CONTACT_I...
# 9  {'applyStartersPreferenceVoid': True, 'company...
#
#                           *savingInfo    new            formattedLocation  \
# 0  urn:li:fs_jobSavingInfo:2789801957  False  Barcelona, Catalonia, Spain
# 1  urn:li:fs_jobSavingInfo:2659225588  False  Barcelona, Catalonia, Spain
# 2  urn:li:fs_jobSavingInfo:2798062915   True  Barcelona, Catalonia, Spain
# 3  urn:li:fs_jobSavingInfo:2794290431  False  Barcelona, Catalonia, Spain
# 4  urn:li:fs_jobSavingInfo:2766593461  False  Barcelona, Catalonia, Spain
# 5  urn:li:fs_jobSavingInfo:2751447445  False  Barcelona, Catalonia, Spain
# 6  urn:li:fs_jobSavingInfo:2755937274  False  Barcelona, Catalonia, Spain
# 7  urn:li:fs_jobSavingInfo:2800730136   True  Barcelona, Catalonia, Spain
# 8  urn:li:fs_jobSavingInfo:2788830334  False  Barcelona, Catalonia, Spain
# 9  urn:li:fs_jobSavingInfo:2770419858  False  Barcelona, Catalonia, Spain
#
#         expireAt       listedAt  \
# 0  1639146072000  1636554073000
# 1  1642549517000  1636198129000
# 2  1639836017000  1637244017000
# 3  1639655209000  1637063210000
# 4  1640185477000  1636895107000
# 5  1639302854000  1636016771000
# 6  1639826367000  1636457147000
# 7  1639836082000  1637244082000
# 8  1639071464000  1636479465000
# 9  1638038827000  1635446828000
#
#                                         $recipeTypes  \
# 0  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 1  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 2  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 3  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 4  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 5  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 6  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 7  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 8  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 9  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
#
#                                   $type standardizedAddresses  \
# 0  com.linkedin.voyager.jobs.JobPosting                  None
# 1  com.linkedin.voyager.jobs.JobPosting                  None
# 2  com.linkedin.voyager.jobs.JobPosting                  None
# 3  com.linkedin.voyager.jobs.JobPosting                  None
# 4  com.linkedin.voyager.jobs.JobPosting                  None
# 5  com.linkedin.voyager.jobs.JobPosting                  None
# 6  com.linkedin.voyager.jobs.JobPosting                  None
# 7  com.linkedin.voyager.jobs.JobPosting                  None
# 8  com.linkedin.voyager.jobs.JobPosting                  None
# 9  com.linkedin.voyager.jobs.JobPosting                  None
#
#                           sourceDomain
# 0  dxctechnology.wd1.myworkdayjobs.com
# 1                         jobs.sap.com
# 2                                 None
# 3                                 None
# 4                    app.greenhouse.io
# 5               www.careers.zurich.com
# 6                      www.amazon.jobs
# 7                    app.greenhouse.io
# 8                                 None
# 9                   careers.criteo.com

# %%
#Con Regex voy a extraer los ids de las empresas
company_reference = r'([0-9]+)'

# %%
#Los almacenaré en CompanyId
jobs_df['CompanyId']=None

# %%
index_description= jobs_df.columns.get_loc('companyDetails')
index_date = jobs_df.columns.get_loc('CompanyId')
print(index_description, index_date)
# Out:
# 2 18

# %%
jobs_df['JobId']=None
jobs_df['companyDetails']=jobs_df['companyDetails'].astype(str)

# %%
#Con un for hago el regex en toda la columna y genero la nueva
for row in range(0,len(jobs_df)):
        if re.search(company_reference, jobs_df.iat[row,index_description]) != None:
            reference = re.search(company_reference, jobs_df.iat[row,index_description]).group()
            jobs_df.iat[row, index_date] = reference
        else:
            reference = None

# %%
#La almaceno en una lista visto que no la puedo trabajar desde el df
companies = list(jobs_df['CompanyId'])

# %%
#Hago lo mismo con el job reference
job_reference = r'([0-9]+)'

# %%
#Definiremos los indices de estas columnas
index_description= jobs_df.columns.get_loc('*savingInfo')
index_date = jobs_df.columns.get_loc('JobId')
print(index_description, index_date)
# Out:
# 9 19

# %%
for row in range(0,len(jobs_df)):
        if re.search(job_reference, jobs_df.iat[row,index_description]) != None:
            reference = re.search(job_reference, jobs_df.iat[row,index_description]).group()
            jobs_df.iat[row, index_date] = reference
        else:
            reference = None

# %%
jobs_df
# Out:
#                                       salaryInsights  \
# 0  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 1  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 2  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 3  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 4  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 5  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 6  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 7  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 8  {'lockModuleShown': True, 'salaryExplorerUrl':...
# 9  {'lockModuleShown': True, 'salaryExplorerUrl':...
#
#                       dashEntityUrn  \
# 0  urn:li:fsd_jobPosting:2789801957
# 1  urn:li:fsd_jobPosting:2659225588
# 2  urn:li:fsd_jobPosting:2798062915
# 3  urn:li:fsd_jobPosting:2794290431
# 4  urn:li:fsd_jobPosting:2766593461
# 5  urn:li:fsd_jobPosting:2751447445
# 6  urn:li:fsd_jobPosting:2755937274
# 7  urn:li:fsd_jobPosting:2800730136
# 8  urn:li:fsd_jobPosting:2788830334
# 9  urn:li:fsd_jobPosting:2770419858
#
#                                       companyDetails jobState  \
# 0  {'company': 'urn:li:fs_normalized_company:1619...   LISTED
# 1  {'company': 'urn:li:fs_normalized_company:1115...   LISTED
# 2  {'company': 'urn:li:fs_normalized_company:1829...   LISTED
# 3  {'company': 'urn:li:fs_normalized_company:7087...   LISTED
# 4  {'company': 'urn:li:fs_normalized_company:9262...   LISTED
# 5  {'company': 'urn:li:fs_normalized_company:2458...   LISTED
# 6  {'company': 'urn:li:fs_normalized_company:1586...   LISTED
# 7  {'company': 'urn:li:fs_normalized_company:9262...   LISTED
# 8  {'company': 'urn:li:fs_normalized_company:2289...   LISTED
# 9  {'company': 'urn:li:fs_normalized_company:3720...   LISTED
#
#                                                title duration  \
# 0                 Intern Masters Business (51006201)     None
# 1         SAP iXp Intern - Digital Demand Strategist     None
# 2                                 Performance Intern     None
# 3                 User Support Representative Intern     None
# 4                     Expansion Intern (They/She/He)     None
# 5                 Performance Management / MI Intern     None
# 6               Business Intelligence Intern - Spain     None
# 7                People Process Intern (They/She/He)     None
# 8                            Campaign Manager Intern     None
# 9  Business and Sales Compensation Analyst Intern...     None
#
#                                     entityUrn briefBenefitsDescription  \
# 0  urn:li:fs_normalized_jobPosting:2789801957
# 1  urn:li:fs_normalized_jobPosting:2659225588
# 2  urn:li:fs_normalized_jobPosting:2798062915
# 3  urn:li:fs_normalized_jobPosting:2794290431
# 4  urn:li:fs_normalized_jobPosting:2766593461
# 5  urn:li:fs_normalized_jobPosting:2751447445
# 6  urn:li:fs_normalized_jobPosting:2755937274
# 7  urn:li:fs_normalized_jobPosting:2800730136
# 8  urn:li:fs_normalized_jobPosting:2788830334
# 9  urn:li:fs_normalized_jobPosting:2770419858
#
#                                          applyMethod  \
# 0  {'applyStartersPreferenceVoid': True, 'company...
# 1  {'applyStartersPreferenceVoid': True, 'company...
# 2  {'easyApplyUrl': 'https://www.linkedin.com/job...
# 3  {'easyApplyUrl': 'https://www.linkedin.com/job...
# 4  {'applyStartersPreferenceVoid': True, 'company...
# 5  {'applyStartersPreferenceVoid': True, 'company...
# 6  {'applyStartersPreferenceVoid': True, 'company...
# 7  {'applyStartersPreferenceVoid': False, 'compan...
# 8  {'unifyApplyEnabled': True, 'type': 'CONTACT_I...
# 9  {'applyStartersPreferenceVoid': True, 'company...
#
#                           *savingInfo    new            formattedLocation  \
# 0  urn:li:fs_jobSavingInfo:2789801957  False  Barcelona, Catalonia, Spain
# 1  urn:li:fs_jobSavingInfo:2659225588  False  Barcelona, Catalonia, Spain
# 2  urn:li:fs_jobSavingInfo:2798062915   True  Barcelona, Catalonia, Spain
# 3  urn:li:fs_jobSavingInfo:2794290431  False  Barcelona, Catalonia, Spain
# 4  urn:li:fs_jobSavingInfo:2766593461  False  Barcelona, Catalonia, Spain
# 5  urn:li:fs_jobSavingInfo:2751447445  False  Barcelona, Catalonia, Spain
# 6  urn:li:fs_jobSavingInfo:2755937274  False  Barcelona, Catalonia, Spain
# 7  urn:li:fs_jobSavingInfo:2800730136   True  Barcelona, Catalonia, Spain
# 8  urn:li:fs_jobSavingInfo:2788830334  False  Barcelona, Catalonia, Spain
# 9  urn:li:fs_jobSavingInfo:2770419858  False  Barcelona, Catalonia, Spain
#
#         expireAt       listedAt  \
# 0  1639146072000  1636554073000
# 1  1642549517000  1636198129000
# 2  1639836017000  1637244017000
# 3  1639655209000  1637063210000
# 4  1640185477000  1636895107000
# 5  1639302854000  1636016771000
# 6  1639826367000  1636457147000
# 7  1639836082000  1637244082000
# 8  1639071464000  1636479465000
# 9  1638038827000  1635446828000
#
#                                         $recipeTypes  \
# 0  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 1  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 2  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 3  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 4  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 5  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 6  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 7  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 8  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
# 9  [com.linkedin.voyager.deco.jserp.WebSearchJobJ...
#
#                                   $type standardizedAddresses  \
# 0  com.linkedin.voyager.jobs.JobPosting                  None
# 1  com.linkedin.voyager.jobs.JobPosting                  None
# 2  com.linkedin.voyager.jobs.JobPosting                  None
# 3  com.linkedin.voyager.jobs.JobPosting                  None
# 4  com.linkedin.voyager.jobs.JobPosting                  None
# 5  com.linkedin.voyager.jobs.JobPosting                  None
# 6  com.linkedin.voyager.jobs.JobPosting                  None
# 7  com.linkedin.voyager.jobs.JobPosting                  None
# 8  com.linkedin.voyager.jobs.JobPosting                  None
# 9  com.linkedin.voyager.jobs.JobPosting                  None
#
#                           sourceDomain CompanyId       JobId
# 0  dxctechnology.wd1.myworkdayjobs.com  16198010  2789801957
# 1                         jobs.sap.com      1115  2659225588
# 2                                 None  18292426  2798062915
# 3                                 None  70871944  2794290431
# 4                    app.greenhouse.io   9262901  2766593461
# 5               www.careers.zurich.com      2458  2751447445
# 6                      www.amazon.jobs      1586  2755937274
# 7                    app.greenhouse.io   9262901  2800730136
# 8                                 None   2289716  2788830334
# 9                   careers.criteo.com     37209  2770419858

# %%
#Miro que contiene esta funcionalidad de la api y veo que lo que me interesa es el name
api.get_company(2289716)
# Out:
# {'staffingCompany': False,
#  'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#    'entityUrn': 'urn:li:fs_industry:30'}],
#  'callToAction': {'callToActionType': 'VIEW_WEBSITE',
#   'visible': True,
#   'callToActionMessage': {'textDirection': 'USER_LOCALE',
#    'text': 'Visit website'},
#   'url': 'http://www.edreamsodigeo.com'},
#  'staffCount': 1428,
#  'adsRule': 'STANDARD',
#  'companyEmployeesSearchPageUrl': 'https://www.linkedin.com/vsearch/p?f_CC=2289716',
#  'viewerFollowingJobsUpdates': False,
#  'staffCountRange': {'start': 1001, 'end': 5000},
#  'permissions': {'landingPageAdmin': False,
#   'admin': False,
#   'adAccountHolder': False},
#  'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0/1636636337161?e=1645056000&v=beta&t=-n3iNwBlctUiScXgUHqgUCHGyAoQx9aihcwlw55Uc-g',
#       'expiresAt': 1645056000000,
#       'height': 200},
#      {'width': 100,
#       'fileIdentifyingUrlPathSegment': '100_100/0/1636636337161?e=1645056000&v=beta&t=Ilcw2Dv6p_Fq5tUbO17YunrT5-8l-ytijdhzjx8VOfE',
#       'expiresAt': 1645056000000,
#       'height': 100},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400_400/0/1636636337161?e=1645056000&v=beta&t=dkub3MV1hUu1wty2eMpW1VxfXGRaabCjIzYGBAIbXbk',
#       'expiresAt': 1645056000000,
#       'height': 400}],
#     'rootUrl': 'https://media-exp1.licdn.com/dms/image/C4E0BAQG3eTvfVfOoew/company-logo_'}},
#   'type': 'SQUARE_LOGO'},
#  'claimable': False,
#  'affiliatedCompaniesResolutionResults': {'urn:li:fs_normalized_company:382350': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:382350',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:382350',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 3762},
#    'description': "Liligo is a travel search engine which instantly compares available flights on websites of travel agencies and airlines, including low cost companies. Under this brand, we compare car rental deals and hotel rooms as well.\n\nWe got offices in Paris, Budapest and Barcelona with a presence across 4 continents.\n\nOur plan is to steadily improve both our technology and our business, so we are looking for talented people who are passionate and motivated about making an impact and helping us change the world by empowering consumers to find the best travel deals across the web.\n\nLiligo is part of eDreams ODIGEO, one of the world's largest online travel companies and one of the largest European e-commerce businesses. Under its four leading online travel agency brands – eDreams, GO Voyages, Opodo, Travellink, and the metasearch engine Liligo – it offers the best deals in regular flights, low-cost airlines, hotels, cruises, car rental, dynamic packages, holiday packages and travel insurance to make travel easier, more accessible, and better value for the more than 18,5 million customers it serves across 43 markets. eDreams ODIGEO is listed in the Spanish Stock Market.",
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/company/liligo-com',
#    'entityUrn': 'urn:li:fs_normalized_company:382350',
#    'name': 'Liligo',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1582721517005?e=1645056000&v=beta&t=rG-ab9k6M02ej_ifg-QyNIzhjlXk-iUbk0PLS7xmiIY',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1582721517005?e=1645056000&v=beta&t=zJqqXRqPZtCDLRFy4g8s_mJQEevA9FcWL0q7d2ZcqyQ',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1582721517005?e=1645056000&v=beta&t=p9fqiggzHiN8JK1krlZu4USg3ZSJBt1-rEgDMENEt-g',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C4D0BAQFx8y7Lj7STRw/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': False,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'liligo-com'}},
#  'specialities': ['travel',
#   'flights (regular, charter, low cost)',
#   'car rental',
#   'cruises',
#   'vacation packages',
#   'travel insurance',
#   'advertising',
#   'Prime',
#   'AI',
#   'Technology',
#   'Innovation',
#   'Diversity'],
#  'confirmedLocations': [{'country': 'ES',
#    'city': 'Barcelona',
#    'postalCode': '08009',
#    'description': 'eDreams ODIGEO Barcelona',
#    'streetAddressOptOut': False,
#    'headquarter': True,
#    'line1': '67, Bailen'},
#   {'country': 'FR',
#    'geographicArea': 'Ile-de-France',
#    'city': 'Paris',
#    'postalCode': '75008',
#    'description': 'eDreams ODIGEO Paris',
#    'streetAddressOptOut': False,
#    'headquarter': False,
#    'line1': '11, Avenue Delcassé'},
#   {'country': 'DE',
#    'city': 'Hamburg',
#    'postalCode': '20354',
#    'description': 'eDreams ODIGEO Hamburg',
#    'streetAddressOptOut': False,
#    'headquarter': False,
#    'line1': 'Büschstr. 12'},
#   {'country': 'GB',
#    'geographicArea': 'GB',
#    'city': 'London',
#    'postalCode': 'W6 7BA',
#    'description': 'eDreams ODIGEO London',
#    'streetAddressOptOut': False,
#    'headquarter': False,
#    'line1': '26-28 Hammersmith Grove'},
#   {'country': 'IT',
#    'geographicArea': 'Lombardy',
#    'city': 'Milan',
#    'postalCode': '20124',
#    'description': 'eDreams ODIGEO Milan',
#    'streetAddressOptOut': False,
#    'headquarter': False,
#    'line1': 'Via San Gregorio, 34'}],
#  'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:2289716',
#   'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:2289716',
#   'following': False,
#   'followingType': 'DEFAULT',
#   'followerCount': 37236},
#  'viewerEmployee': False,
#  'affiliatedCompaniesWithEmployeesRollup': [],
#  'lcpTreatment': True,
#  'affiliatedCompaniesWithJobsRollup': [],
#  'associatedHashtagsResolutionResults': {'urn:li:fs_contentTopicData:urn:li:hashtag:bigdata': {'feedTopic': {'topic': {'trending': False,
#      'name': '#bigdata',
#      'useCase': 'HASHTAG_FEED',
#      'recommendationTrackingId': '[ÝñýÔúLè\x9cç\x1a@ø¢3±',
#      'backendUrn': 'urn:li:hashtag:bigdata'},
#     'tracking': {'trackingId': 'W93x/dT6TOic5xpA+KIzsQ=='},
#     'entityUrn': 'urn:li:fs_feedTopic:(urn:li:hashtag:bigdata,HASHTAG_FEED)'},
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebContentTopicDataCard',
#    'entityUrn': 'urn:li:fs_contentTopicData:urn:li:hashtag:bigdata',
#    'followAction': {'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:hashtag:bigdata',
#      'followerCount': 7130443,
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_hashtag:bigdata',
#      'following': False,
#      'trackingUrn': 'urn:li:hashtag:bigdata'},
#     'unfollowTrackingActionType': 'unfollowTopic',
#     'followTrackingActionType': 'followTopic',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followTopic'}},
#   'urn:li:fs_contentTopicData:urn:li:hashtag:travel': {'feedTopic': {'topic': {'trending': False,
#      'name': '#travel',
#      'useCase': 'HASHTAG_FEED',
#      'recommendationTrackingId': "Iùèz\x9e'LÒ¯r\x1dÄY\x02¤\x01",
#      'backendUrn': 'urn:li:hashtag:travel'},
#     'tracking': {'trackingId': 'Sfnoep4nTNKvch3EWQKkAQ=='},
#     'entityUrn': 'urn:li:fs_feedTopic:(urn:li:hashtag:travel,HASHTAG_FEED)'},
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebContentTopicDataCard',
#    'entityUrn': 'urn:li:fs_contentTopicData:urn:li:hashtag:travel',
#    'followAction': {'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:hashtag:travel',
#      'followerCount': 6993746,
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_hashtag:travel',
#      'following': False,
#      'trackingUrn': 'urn:li:hashtag:travel'},
#     'unfollowTrackingActionType': 'unfollowTopic',
#     'followTrackingActionType': 'followTopic',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followTopic'}},
#   'urn:li:fs_contentTopicData:urn:li:hashtag:technology': {'feedTopic': {'topic': {'trending': False,
#      'name': '#technology',
#      'useCase': 'HASHTAG_FEED',
#      'recommendationTrackingId': '\x9b\x02\x89-Æ\x87I \x8b¼\x03\x86¼:Qn',
#      'backendUrn': 'urn:li:hashtag:technology'},
#     'tracking': {'trackingId': 'mwKJLcaHSSCLvAOGvDpRbg=='},
#     'entityUrn': 'urn:li:fs_feedTopic:(urn:li:hashtag:technology,HASHTAG_FEED)'},
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebContentTopicDataCard',
#    'entityUrn': 'urn:li:fs_contentTopicData:urn:li:hashtag:technology',
#    'followAction': {'followingInfo': {'followingType': 'DEFAULT',
#      'entityUrn': 'urn:li:fs_followingInfo:urn:li:hashtag:technology',
#      'followerCount': 26434066,
#      'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_hashtag:technology',
#      'following': False,
#      'trackingUrn': 'urn:li:hashtag:technology'},
#     'unfollowTrackingActionType': 'unfollowTopic',
#     'followTrackingActionType': 'followTopic',
#     'type': 'FOLLOW_TOGGLE',
#     'trackingActionType': 'followTopic'}}},
#  'name': 'eDreams ODIGEO',
#  'tagline': 'We are shaping the way people travel today and tomorrow. Our passion is travel, our business is technology. #WeFlyHigh',
#  '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebFullCompanyMain',
#  'fundingData': {'fundingRoundListCrunchbaseUrl': 'https://www.crunchbase.com/organization/edreams-odigeo/funding_rounds/funding_rounds_list?utm_source=linkedin&utm_medium=referral&utm_campaign=linkedin_companies&utm_content=all_fundings',
#   'lastFundingRound': {'investorsCrunchbaseUrl': 'https://www.crunchbase.com/funding_round/edreams-odigeo-series-unknown--727bd877?utm_source=linkedin&utm_medium=referral&utm_campaign=linkedin_companies&utm_content=all_investors',
#    'leadInvestors': [],
#    'fundingRoundCrunchbaseUrl': 'https://www.crunchbase.com/funding_round/edreams-odigeo-series-unknown--727bd877?utm_source=linkedin&utm_medium=referral&utm_campaign=linkedin_companies&utm_content=last_funding',
#    'fundingType': 'SERIES_UNKNOWN',
#    'numOtherInvestors': 1,
#    'announcedOn': {'month': 1, 'day': 1, 'year': 2000}},
#   'companyCrunchbaseUrl': 'https://www.crunchbase.com/organization/edreams-odigeo?utm_source=linkedin&utm_medium=referral&utm_campaign=linkedin_companies&utm_content=profile_cta',
#   'numFundingRounds': 1,
#   'updatedAt': 1594277388},
#  'overviewPhoto': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 900,
#      'fileIdentifyingUrlPathSegment': 'https://media-exp1.licdn.com/dms/image/C4D1CAQFjvqLA3AO9Dg/company-overview_900_300/0/1525342053489?e=1637366400&v=beta&t=5VzhYSeAF4tQRrZNGpZJP60tiJCqg2jhhX4SCtdcj-Q',
#      'expiresAt': 1637366400000,
#      'height': 300}],
#    'rootUrl': ''}},
#  'multiLocaleTaglines': {'localized': {'en_US': 'We are shaping the way people travel today and tomorrow. Our passion is travel, our business is technology. #WeFlyHigh'},
#   'preferredLocale': {'country': 'US', 'language': 'en'}},
#  'description': "eDreams ODIGEO is one of the world's largest online travel companies and one of the largest European e-commerce businesses. Under its four leading online travel agency brands – eDreams, GO Voyages, Opodo, Travellink, and the metasearch engine Liligo – it offers the best deals in regular flights, low-cost airlines, hotels, cruises, car rental, dynamic packages, holiday packages and travel insurance as well as innovative services such as Prime, the very first subscription programme ever created in travel, to make travel easier, more accessible, and better value for the more than 17 million customers it serves across 45 markets. eDreams ODIGEO is listed in the Spanish Stock Market.\n\nBecause we are growing rapidly globally, we are covering more and more regions. As a result, we are culturally diverse, with more than 65 different nationalities represented throughout the group.\n\n#WE FLY HIGH\n#WE SET THE PATH\n#WE JOURNEY TOGETHER\n#WE EXPLORE ... GROW AND DISCOVER!\n\n",
#  'entityUrn': 'urn:li:fs_normalized_company:2289716',
#  'headquarter': {'country': 'ES',
#   'city': 'Barcelona',
#   'postalCode': '08009',
#   'line1': '67, Bailen'},
#  'showcasePagesResolutionResults': {'urn:li:fs_normalized_company:33226437': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:33226437',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:33226437',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 812},
#    'description': 'eDreams ODIGEO Connect is the platform created for hoteliers to help them advertise their hotel, B&B or apartment on eDreams ODIGEO brands (eDreams, Opodo, GoVoyages and Travellink) in a package offer. \n\nProperties are displayed to travellers in combination with a flight.',
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/showcase/edreams-odigeo-connect',
#    'entityUrn': 'urn:li:fs_normalized_company:33226437',
#    'name': 'eDreams ODIGEO Connect',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1578389567658?e=1645056000&v=beta&t=XgRwUeiJqscgzj29dQ3_zNkSWlXol0y1hzj1kGVfO80',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1578389567658?e=1645056000&v=beta&t=i6iwEIUpKPTP13xn4bazh6DWvrD3YXquZVjeXZ_LosU',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1578389567658?e=1645056000&v=beta&t=89EHTxT7kicG8XyqPPatwnYmuaQPqHze1hoW5m564k8',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C560BAQHjAXtJezYTrw/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'edreams-odigeo-connect'},
#   'urn:li:fs_normalized_company:20741': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:20741',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:20741',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 55178},
#    'description': 'eDreams is the largest independent european online travel agency. Its head-office is situated in Barcelona, Spain. eDreams focuses on offering the best selection of flights, hotels and vacation packag',
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/showcase/edreams',
#    'entityUrn': 'urn:li:fs_normalized_company:20741',
#    'name': 'eDreams',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1519856165327?e=1645056000&v=beta&t=UqaH-tOBtFaAXUIcX57d1vAq-jh4nxZY_16Rbm1_A3g',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1519856165327?e=1645056000&v=beta&t=W-mM4V3ze0T3JR8pZ1NMrE_5v7NlgGWVKpgVzWbmZFE',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1519856165327?e=1645056000&v=beta&t=xGmJCRkoB9M7esXdF2YYfOZRTSEoqIt6fMnsn2FSp6c',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C4D0BAQHifHiiWvRTcg/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'edreams'},
#   'urn:li:fs_normalized_company:18682397': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:18682397',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:18682397',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 200},
#    'description': 'Who are we?\n\nOur airline relationship managers are all experienced airliners\n\nWe understand your objectives and your challenges. We are experts supporting your sales growth.\n\n\nWhy work with us? \n\nPERFORMANCE DATA\n\nOur data intelligence and analysis is fully adapted to provide rich performance information to airlines.\n\nOur huge volumes allow us to benchmark airlines versus their competitors within the industry.\n\nOur data reach is representative for Europe, including Low Cost and Airline Mix\n\n\nAIR FARES\n\nWe have a dedicated fare expert team.\n\nWe can load your fares, which decreases time-to-market and can reduce your costs.\n\nWe promote all kinds of special fares, such as APP fares, Prime fares, mobile-fares, package-fares, seat-only exclusive fares, dynamic discounts.\n\n\nSALES\n\nWe provide different steering methods to our partner airlines, including real-time-yield-management.\n\nIf you have distressed inventory, we can fill planes at short notice.\n\nWe boost your ancillary sales.\n\n\nECOMMERCE SERVICES & TECHNOLOGY\n\nWe power your website from A-Z with the most sophisticated technology and methods.\n\nWe deliver special services to your eCommerce area like fraud protection services, user experience services, agile set-up masterclasses.\n\n \nContact us: air.supply@edreamsodigeo.com',
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/showcase/edo-air-supply',
#    'entityUrn': 'urn:li:fs_normalized_company:18682397',
#    'name': 'eDreams ODIGEO Air Supply',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1529478253764?e=1645056000&v=beta&t=I5y_xNayswQa0RUPB8AM150JklyTlS7cUfdTrQBlYYs',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1529478253764?e=1645056000&v=beta&t=ziwIcIBaknmrWCgOKRu9hLTJI3BbzojmMUAg5cZoqZ4',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1529478253764?e=1645056000&v=beta&t=ohywVDLrzxqiqEFlHrls1mbI3xApsu1whnV3oBe24as',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C560BAQHbR9-16POGPw/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'edo-air-supply'},
#   'urn:li:fs_normalized_company:38279': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:38279',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:38279',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 2214},
#    'description': 'Travellink är Nordens ledande internetresebyrå med verksamhet i Sverige, Norge, Danmark och Finland. Travellink säljer flygresor från 440 olika flygbolag och över 460 000 hotell till mer än 40 000 des',
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/showcase/travellink',
#    'entityUrn': 'urn:li:fs_normalized_company:38279',
#    'name': 'Travellink',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1519856993241?e=1645056000&v=beta&t=2-gEVpe8cxAw_3xXZOt-J_QPu9Rb-8vTwQxHeF_BlM0',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1519856993241?e=1645056000&v=beta&t=ozsMFVsifqfB0MsqxGibi8F18s9UbaC-e7vpb43jj4M',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1519856993241?e=1645056000&v=beta&t=u4CKGs5NfPQiD0cR867mKpKjsu8-Itgjq06tt7rKXo8',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C510BAQEiYKtLGNS7ww/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'travellink'},
#   'urn:li:fs_normalized_company:18650804': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:18650804',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:18650804',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 304},
#    'description': 'We are Global experts in advertising content and digital marketing. \n\nWith teams situated across the key markets in Europe, the eDreams ODIGEO Media Services team offers solution oriented and tailored marketing plans to meet a variety of client needs.\n\neDreams ODIGEO offers a multitude of ways to reach potential customers, from branding and performance campaigns across our global domains, to audience extension campaigns using our qualified data to reach relevant audiences.\n\nFor more information, or to contact one of our experts and find out how we can help you grow your business please visit https://advertising.edreamsodigeo.com/',
#    'companyIndustries': [{'localizedName': 'Marketing & Advertising',
#      'entityUrn': 'urn:li:fs_industry:80'}],
#    'url': 'https://www.linkedin.com/showcase/edo-media-services',
#    'entityUrn': 'urn:li:fs_normalized_company:18650804',
#    'name': 'eDreams ODIGEO Media Services',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1527247401516?e=1645056000&v=beta&t=rsC4gcvoyfULDyCMQOkyUoDky10o9mHgKp75L3dEuXY',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1527247401516?e=1645056000&v=beta&t=-UB-D4D5yx_ahd2BgdcPCfzKuhfsQjFhf7cGLbWqo1E',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1527247401516?e=1645056000&v=beta&t=0qctWmmULviulaizstnbSKftHkEbH_rAoVAwydw3H9w',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C560BAQGHgTJXe1PZPQ/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'edo-media-services'},
#   'urn:li:fs_normalized_company:134168': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:134168',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:134168',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 3841},
#    'description': 'Partez en vacances avec GO Voyages, l’agence de voyage en ligne leader en France : en partenariat avec plus de 500 compagnies aériennes, elle propose les billets d’avion les plus avantageux du marché ',
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/showcase/go-voyages',
#    'entityUrn': 'urn:li:fs_normalized_company:134168',
#    'name': 'GO Voyages',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1519902987614?e=1645056000&v=beta&t=s7aWH_dqUYez3ip0OONV5qHzhN6-piOvu-k0QLP5hCE',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1519902987614?e=1645056000&v=beta&t=bPjO17xnggVb7dJIys4s3ZuK0tpGyH-GPV6PJgUBuqE',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1519902987614?e=1645056000&v=beta&t=ZDO6AlkRmDAvmeII-Y1q4xaUirn5IJvGK3jBgwRfwKQ',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C560BAQHf3QPgxjNQGg/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'go-voyages'},
#   'urn:li:fs_normalized_company:7883': {'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:7883',
#     'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:7883',
#     'following': False,
#     'followingType': 'DEFAULT',
#     'followerCount': 8869},
#    'description': "Opodo is a leading pan-European online travel agency specialising in worldwide travel. \r\nIt was founded by nine of Europe's top airlines and is part of the eDreams ODIGEO Group which also encompasses ",
#    'companyIndustries': [{'localizedName': 'Leisure, Travel & Tourism',
#      'entityUrn': 'urn:li:fs_industry:30'}],
#    'url': 'https://www.linkedin.com/showcase/opodo',
#    'entityUrn': 'urn:li:fs_normalized_company:7883',
#    'name': 'Opodo',
#    'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#         'fileIdentifyingUrlPathSegment': '200_200/0/1519856136471?e=1645056000&v=beta&t=EmW9tU1eV7LBlPGmGMMoGbNWc7N0GPuXiPFQ4sVcrKU',
#         'expiresAt': 1645056000000,
#         'height': 200},
#        {'width': 100,
#         'fileIdentifyingUrlPathSegment': '100_100/0/1519856136471?e=1645056000&v=beta&t=AdNdTaV5Ug8idb9VE00ysr6xc0SjzBGqGuz0bsVTGk0',
#         'expiresAt': 1645056000000,
#         'height': 100},
#        {'width': 400,
#         'fileIdentifyingUrlPathSegment': '400_400/0/1519856136471?e=1645056000&v=beta&t=3bHYA63dw-p0wWASQRUOSN4M2gdVEvOEyYIN38Njzq8',
#         'expiresAt': 1645056000000,
#         'height': 400}],
#       'rootUrl': 'https://media-exp1.licdn.com/dms/image/C4E0BAQFUyP636gkY-Q/company-logo_'}},
#     'type': 'SQUARE_LOGO'},
#    'paidCompany': False,
#    'showcase': True,
#    '$recipeType': 'com.linkedin.voyager.deco.organization.web.WebCompanyCard',
#    'universalName': 'opodo'}},
#  'paidCompany': True,
#  'universalName': 'edreamsodigeo',
#  'viewerPendingAdministrator': False,
#  'companyPageUrl': 'http://www.edreamsodigeo.com',
#  'viewerConnectedToAdministrator': False,
#  'affiliatedCompanies': ['urn:li:fs_normalized_company:382350'],
#  'dataVersion': -1,
#  'foundedOn': {'year': 2000},
#  'companyType': {'localizedName': 'Public Company', 'code': 'PUBLIC_COMPANY'},
#  'coverPhoto': {'com.linkedin.voyager.common.MediaProcessorImage': {'id': '/AAEAAQAAAAAAAAezAAAAJDEwOWFmZGVlLTZhM2ItNDgwYi04ZjRmLWJhMzljOGY5NWM1Zg.png'}},
#  'associatedHashtags': ['urn:li:fs_contentTopicData:urn:li:hashtag:technology',
#   'urn:li:fs_contentTopicData:urn:li:hashtag:travel',
#   'urn:li:fs_contentTopicData:urn:li:hashtag:bigdata'],
#  'groups': [],
#  'url': 'https://www.linkedin.com/company/edreamsodigeo',
#  'showcasePages': ['urn:li:fs_normalized_company:18682397',
#   'urn:li:fs_normalized_company:20741',
#   'urn:li:fs_normalized_company:38279',
#   'urn:li:fs_normalized_company:18650804',
#   'urn:li:fs_normalized_company:134168',
#   'urn:li:fs_normalized_company:7883',
#   'urn:li:fs_normalized_company:33226437'],
#  'claimableByViewer': False,
#  'jobSearchPageUrl': 'https://www.linkedin.com/jobs/search?geoId=92000000&f_C=2289716',
#  'showcase': False,
#  'autoGenerated': False,
#  'backgroundCoverImage': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 10000,
#       'fileIdentifyingUrlPathSegment': '10000/0/1637141955565?e=1637366400&v=beta&t=QwfTMiVtwPS79JL2-cCwb0C3Cy-QaRyAYnfyPlqDz3g',
#       'expiresAt': 1637366400000,
#       'height': 10000},
#      {'width': 400,
#       'fileIdentifyingUrlPathSegment': '400/0/1637141955565?e=1637366400&v=beta&t=H66saz0DQez_3fCUZdl6XsCABUCpJu7NXDj48BnR5mY',
#       'expiresAt': 1637366400000,
#       'height': 400},
#      {'width': 200,
#       'fileIdentifyingUrlPathSegment': '200/0/1637141955565?e=1637366400&v=beta&t=nLWeL7Zo7h0wmUMm3RNj3kLqGZLL0mALjnN2X5FwjW8',
#       'expiresAt': 1637366400000,
#       'height': 200}],
#     'rootUrl': 'https://media-exp1.licdn.com/dms/image/C4E1BAQFnOqjtd8Z4VA/company-background_'}},
#   'cropInfo': {'x': 0, 'width': 1536, 'y': 60, 'height': 260}}}

# %%
#Intento extraer el name pero no sé acceder a él, estoy haciendo pruebas para poder extraer el name
# de al menos una para poder aplicarlo al resto posteriormente

company_n = api.get_company(2289716)
company_name = [company_n['name'] for name in affiliatedCompaniesResolutionResults]
company_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/x4/j5splm5d1yv_0jpj70nz1mvc0000gn/T/ipykernel_86185/2070638841.py in <module>
#       2 # de al menos una para poder aplicarlo al resto posteriormente
#       3 company_n = api.get_company(2289716)
# ----> 4 company_name = [company_n['name'] for name in affiliatedCompaniesResolutionResults]
#       5 company_name
#
# NameError: name 'affiliatedCompaniesResolutionResults' is not defined

# %%
company_name_df = pd.DataFrame(company_name)

# %%
#La idea es generar un loop y sacar todos los nombres de las compañías
#además de, a poder ser, el id de la compañia para margear el nombre de nuevo a la dataframe inicial
companies_df=[]
for id in companies:
    company_name = api.get_company(id)
    company_name_df = pd.DataFrame(company_name)
    company=company_name_df['name']
    companies_df.append(
    {'Company':company
    })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x4/j5splm5d1yv_0jpj70nz1mvc0000gn/T/ipykernel_86185/1154333928.py in <module>
#       2 for id in companies:
#       3     company_name = api.get_company(id)
# ----> 4     company_name_df = pd.DataFrame(company_name)
#       5     company=company_name_df['name']
#       6     companies_df.append(
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# # Scrapping:
#
# La idea es scrapear las ofertas una por una para extraer la descripción y añadirla al dataframe.

# %%
geckodriver_autoinstaller.install()
# Out:
# '/usr/local/lib/python3.9/site-packages/geckodriver_autoinstaller/v0.30.0/geckodriver'

# %%
driver = webdriver.Firefox()

# %%
jobs_df.astype({'JobId': 'int32'}).dtypes
jobs = list(jobs_df['JobId'])

# %%
jobs
# Out:
# ['2789801957',
#  '2659225588',
#  '2798062915',
#  '2794290431',
#  '2766593461',
#  '2751447445',
#  '2755937274',
#  '2800730136',
#  '2788830334',
#  '2770419858']

# %%
driver.get('http://linkedin.com/')

# %%
usuario_ref = driver.find_element(by='id',value='session_key')
password_ref = driver.find_element(by='id',value='session_password')

login = driver.find_element(by = 'css selector',value = '.sign-in-form__submit-button')

# %%
usuario_ref.send_keys(usuario)

# %%
password_ref.send_keys(password)

# %%
login.click()

# %%
driver.page_source
# Out:
# '<html class="theme theme--mercado artdeco osx" lang="es"><head>\n    <script type="text/javascript" async="" charset="utf-8" id="utag_129" src="https://platform.linkedin.com/litms/vendor/google/gtag-adwords.js?id=AW-979305453"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <title>(1) Feed | LinkedIn</title>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb">\n    <meta name="description" content="">\n    <meta name="google" content="notranslate">\n    <meta name="service" content="voyager-web">\n    <meta name="theme-color" content="#ffffff" id="theme-color-meta-tag">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <meta name="baseCDNUrl" content="https://static-exp1.licdn.com/sc/h">\n    <link rel="manifest" href="https://static-exp1.licdn.com/sc/h/8ekldmhv4d8prk5sml735t6np">\n\n    \n        <link id="ui-theme" rel="stylesheet" href="https://static-exp1.licdn.com/sc/h/6mq9z5sapu1tra24pld2zctdw">\n        <link id="ui-theme-dark" rel="stylesheet" href="https://static-exp1.licdn.com/sc/h/8omz7ffov9dtw1n13lpi2ltq5" disabled="">\n      \n    <link rel="stylesheet" href="https://static-exp1.licdn.com/sc/h/6pt0354ltxoiwiaugx9k0kd5l">\n    \n<meta name="extended/config/environment" content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22aide%22%3A%7B%22isIsolatedBuild%22%3Afalse%7D%2C%22client-sensor-web%22%3A%7B%22mpName%22%3A%22voyager-web%22%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-fetch%22%3A%7B%22preferNative%22%3Atrue%7D%2C%22image-editor%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Atrue%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%2C%22web-vitals-enabled%22%3Atrue%2C%22enable-memory-measurement%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%220.0.0-productspec%2B64f8ee75%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.youtube-nocookie.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%20*.youtube-nocookie.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22validation%22%3A%7B%22throwOnError%22%3Atrue%7D%2C%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%2 ...

# %%
jobs_complete=[]

for reference in jobs:
    job_url=f'https://www.linkedin.com/jobs/search/?currentJobId={reference}'
    print(job_url)
    try:
        driver.get(job_url)
        ele = driver.find_element(by='id', value = 'job-details')
        jobs_complete.append(
        {'job_description': ele.text,
         'url': ele.get_attribute('href')
        })
        time.sleep(20)
    except:
        print("Not possible")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f362e0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124941730>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f36220>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124616f10>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x12464d730>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1247fe310>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1247fe970>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124616ca0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1248a80a0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1247feca0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1247fe6d0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1247fe220>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f36c10>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f36310>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f362b0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f505e0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x111611d30>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f50f40>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f84ac0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f50820>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f84be0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1248a8be0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1248a8070>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f84c40>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x111611d30>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1247b7460>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f501c0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124941760>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f50bb0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x124f509a0>: Failed to establish a new connection: [Errno 61] Connection refused')': /session/bc35055e-94f5-8641-9660-42011b5df77b/url
# https://www.linkedin.com/jobs/search/?currentJobId=2789801957
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2659225588
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2798062915
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2794290431
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2766593461
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2751447445
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2755937274
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2800730136
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2788830334
# Not possible
# https://www.linkedin.com/jobs/search/?currentJobId=2770419858
# Not possible

# %%
jobs_complete
# Out:
# []
