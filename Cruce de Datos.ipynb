# %%
import pandas as pd
import numpy as np

justETF = pd.read_csv('justETF.csv')

# %%
justETF=justETF.replace(['-'], np.nan )

# %%
justETF['Fund size [M]'] = justETF['Fund size [M]'].str.replace(',','').astype(float)

# %%
for column in justETF.columns[5:]:
   justETF[column] = justETF[column].str.replace('%','').astype(float)

# %%
D = pd.read_csv('etfs.csv')

# %%
pd.merge(df1['isin'].drop_duplicates(), df2, how='inner',left_on='isin',right_on='ISIN')
# Out:
#               isin                                               name  \
# 0     IE00B1XNHC34              iShares Global Clean Energy UCITS ETF
# 1     IE00B3XXRP09                         Vanguard S&P 500 UCITS ETF
# 2     IE00B3RBWM25     Vanguard FTSE All-World UCITS ETF Distributing
# 3     IE00B4L5Y983        iShares Core MSCI World UCITS ETF USD (Acc)
# 4     IE0005042456             iShares Core FTSE 100 UCITS ETF (Dist)
# ...            ...                                                ...
# 1287  IE00BHZPHZ28  iShares MSCI EMU ESG Enhanced UCITS ETF EUR (D...
# 1288  IE00BYSX4846  Fidelity Emerging Markets Quality Income UCITS...
# 1289  DE000ETFL425      Deka Deutsche Boerse EUROGOV France UCITS ETF
# 1290  IE00BF1QPH33  SPDR Bloomberg Barclays Global Aggregate Bond ...
# 1291  LU2082997789  Lyxor STOXX Europe 600 Industrial Goods & Serv...
#
#               ISIN Ticker   Fund CCY  Fund size [M]  TER in % p.a.  1Y in %  \
# ...
